# %%
import pandas as pd
from urllib.request import Request, urlopen
from bs4 import BeautifulSoup as bs
import re
from multiprocessing import Pool

# %%
birds_list = pd.read_csv("birds_list.csv")

# %%
birds_list.head(50)
# Out:
#     Unnamed: 0               Common name                     Binomial  \
# 0            0        Southern cassowary          Casuarius casuarius
# 1            1                       Emu     Dromaius novaehollandiae
# 2            2           King Island emu                Dromaius ater
# 3            3       Kangaroo Island emu         Dromaius baudinianus
# 4            4    Australian brushturkey             Alectura lathami
# 5            5                Malleefowl              Leipoa ocellata
# 6            6   Orange-footed scrubfowl         Megapodius reinwardt
# 7            7             Stubble quail          Coturnix pectoralis
# 8            8               Brown quail         Coturnix ypsilophora
# 9            9                King quail      Excalfactoria chinensis
# 10          10            Indian peafowl               Pavo cristatus
# 11          11            Red junglefowl                Gallus gallus
# 12          12          Green junglefowl                Gallus varius
# 13          13           Common pheasant          Phasianus colchicus
# 14          14               Wild turkey          Meleagris gallopavo
# 15          15       Helmeted guineafowl             Numida meleagris
# 16          16              Magpie goose        Anseranas semipalmata
# 17          17    Spotted whistling duck          Dendrocygna guttata
# 18          18     Plumed whistling duck           Dendrocygna eytoni
# 19          19  Wandering whistling duck          Dendrocygna arcuata
# 20          20                 Musk duck               Biziura lobata
# 21          21             Freckled duck          Stictonetta naevosa
# 22          22         Cape Barren goose    Cereopsis novaehollandiae
# 23          23                Black swan               Cygnus atratus
# 24          24                 Mute swan                  Cygnus olor
# 25          25              Canada goose            Branta canadensis
# 26          26           Radjah shelduck               Tadorna radjah
# 27          27       Australian shelduck          Tadorna tadornoides
# 28          28         Paradise shelduck            Tadorna variegata
# 29          29      Australian wood duck            Chenonetta jubata
# 30          30           Pink-eared duck  Malacorhynchus membranaceus
# 31          31        Cotton pygmy goose     Nettapus coromandelianus
# 32          32         Green pygmy goose          Nettapus pulchellus
# 33          33                  Garganey             Anas querquedula
# 34          34     Australasian shoveler              Anas rhynchotis
# 35          35         Northern shoveler                Anas clypeata
# 36          36                 Grey teal                Anas gracilis
# 37          37             Chestnut teal                Anas castanea
# 38          38          Northern pintail                   Anas acuta
# 39          39          Northern mallard           Anas platyrhynchos
# 40          40        Pacific black duck            Anas superciliosa
# 41          41                  Hardhead             Aythya australis
# 42          42          Blue-billed duck             Oxyura australis
# 43          43     Red-tailed tropicbird          Phaethon rubricauda
# 44          44   White-tailed tropicbird            Phaethon lepturus
# 45          45        Australasian grebe  Tachybaptus novaehollandiae
# 46          46              Little grebe       Tachybaptus ruficollis
# 47          47        Hoary-headed grebe  Poliocephalus poliocephalus
# 48          48       Great crested grebe           Podiceps cristatus
# 49          49               Rock pigeon                Columba livia
#
#                                   Notes                Category  \
# 0                                   NaN             Cassowaries
# 1                                   NaN                    Emus
# 2                               extinct                    Emus
# 3                               extinct                    Emus
# 4                                   NaN          Mound-builders
# 5                                   NaN          Mound-builders
# 6                                   NaN          Mound-builders
# 7                                   NaN               Pheasants
# 8                                   NaN               Pheasants
# 9                                   NaN               Pheasants
# 10                           introduced               Pheasants
# 11                           introduced               Pheasants
# 12  introduced, Cocos (Keeling) Islands               Pheasants
# 13                           introduced               Pheasants
# 14                           introduced               Pheasants
# 15                           introduced              Guineafowl
# 16                                  NaN            Magpie goose
# 17                                  NaN  Ducks, geese and swans
# 18                                  NaN  Ducks, geese and swans
# 19                                  NaN  Ducks, geese and swans
# 20                                  NaN  Ducks, geese and swans
# 21                                  NaN  Ducks, geese and swans
# 22                                  NaN  Ducks, geese and swans
# 23                                  NaN  Ducks, geese and swans
# 24                           introduced  Ducks, geese and swans
# 25                  vagrant, introduced  Ducks, geese and swans
# 26                                  NaN  Ducks, geese and swans
# 27                                  NaN  Ducks, geese and swans
# 28            vagrant, Lord Howe Island  Ducks, geese and swans
# 29                                  NaN  Ducks, geese and swans
# 30                                  NaN  Ducks, geese and swans
# 31                                  NaN  Ducks, geese and swans
# 32                                  NaN  Ducks, geese and swans
# 33                                  NaN  Ducks, geese and swans
# 34                                  NaN  Ducks, geese and swans
# 35                              vagrant  Ducks, geese and swans
# 36                                  NaN  Ducks, geese and swans
# 37                                  NaN  Ducks, geese and swans
# 38                              vagrant  Ducks, geese and swans
# 39                           introduced  Ducks, geese and swans
# 40                                  NaN  Ducks, geese and swans
# 41                                  NaN  Ducks, geese and swans
# 42                                  NaN  Ducks, geese and swans
# 43                                  NaN             Tropicbirds
# 44                                  NaN             Tropicbirds
# 45                                  NaN                  Grebes
# 46                              vagrant                  Grebes
# 47                                  NaN                  Grebes
# 48                                  NaN                  Grebes
# 49                           introduced       Pigeons and doves
#
#                Order         Family  colour  size
# 0      Casuariformes    Casuariidae     NaN   NaN
# 1      Casuariformes     Dromaiidae     NaN   NaN
# 2      Casuariformes     Dromaiidae     NaN   NaN
# 3      Casuariformes     Dromaiidae     NaN   NaN
# 4        Galliformes    Megapodidae     NaN   NaN
# 5        Galliformes    Megapodidae     NaN   NaN
# 6        Galliformes    Megapodidae     NaN   NaN
# 7        Galliformes    Phasianidae     NaN   NaN
# 8        Galliformes    Phasianidae     NaN   NaN
# 9        Galliformes    Phasianidae     NaN   NaN
# 10       Galliformes    Phasianidae     NaN   NaN
# 11       Galliformes    Phasianidae     NaN   NaN
# 12       Galliformes    Phasianidae     NaN   NaN
# 13       Galliformes    Phasianidae     NaN   NaN
# 14       Galliformes    Phasianidae     NaN   NaN
# 15       Galliformes      Numididae     NaN   NaN
# 16      Anseriformes  Anseranatidae     NaN   NaN
# 17      Anseriformes       Anatidae     NaN   NaN
# 18      Anseriformes       Anatidae     NaN   NaN
# 19      Anseriformes       Anatidae     NaN   NaN
# 20      Anseriformes       Anatidae     NaN   NaN
# 21      Anseriformes       Anatidae     NaN   NaN
# 22      Anseriformes       Anatidae     NaN   NaN
# 23      Anseriformes       Anatidae     NaN   NaN
# 24      Anseriformes       Anatidae     NaN   NaN
# 25      Anseriformes       Anatidae     NaN   NaN
# 26      Anseriformes       Anatidae     NaN   NaN
# 27      Anseriformes       Anatidae     NaN   NaN
# 28      Anseriformes       Anatidae     NaN   NaN
# 29      Anseriformes       Anatidae     NaN   NaN
# 30      Anseriformes       Anatidae     NaN   NaN
# 31      Anseriformes       Anatidae     NaN   NaN
# 32      Anseriformes       Anatidae     NaN   NaN
# 33      Anseriformes       Anatidae     NaN   NaN
# 34      Anseriformes       Anatidae     NaN   NaN
# 35      Anseriformes       Anatidae     NaN   NaN
# 36      Anseriformes       Anatidae     NaN   NaN
# 37      Anseriformes       Anatidae     NaN   NaN
# 38      Anseriformes       Anatidae     NaN   NaN
# 39      Anseriformes       Anatidae     NaN   NaN
# 40      Anseriformes       Anatidae     NaN   NaN
# 41      Anseriformes       Anatidae     NaN   NaN
# 42      Anseriformes       Anatidae     NaN   NaN
# 43  Phaethontiformes  Phaethontidae     NaN   NaN
# 44  Phaethontiformes  Phaethontidae     NaN   NaN
# 45  Podicipediformes  Podicipedidae     NaN   NaN
# 46  Podicipediformes  Podicipedidae     NaN   NaN
# 47  Podicipediformes  Podicipedidae     NaN   NaN
# 48  Podicipediformes  Podicipedidae     NaN   NaN
# 49     Columbiformes     Columbidae     NaN   NaN

# %%
birds_list['Common_name_lowercase'] = birds_list['Common name'].str.lower()
birds_list['Common_name_lowercase'] = birds_list['Common_name_lowercase'].str.replace(' ', '-')

# %%
link_prefix = 'http://www.oiseaux-birds.com/'
birds_list['link'] = link_prefix + 'card-' + birds_list['Common_name_lowercase'] + '.html'

# %%
ERROR_PAGE_LEN = 2282

# %%
url = "http://www.oiseaux-birds.com/card-southern-cassowary.html"
req = Request(url, headers={'User-Agent': 'Mozilla/5.0'})
webpage = urlopen(req).read()
webpage_str = str(webpage)
soup = bs(webpage, "lxml")

# %%
height = re.search('Height:(.*?)<br />', webpage_str)
if height:
    height = height.group(1).strip()
else:
    height = pd.np.nan

# %%
length = re.search('Length:(.*?)<br />', webpage_str)
if length:
    length = length.group(1).strip()
else:
    length = pd.np.nan

# %%
weight = re.search('Weight:(.*?)</p>', webpage_str)
if weight:
    weight = weight.group(1).strip()
else:
    weight = pd.np.nan

# %%
imgs = soup.find_all("img")
if imgs:
    imgs = [link_prefix + img['src'] for img in imgs]
else:
    imgs = pd.np.nan

# %%
voice = re.search('VOICE(.*?)</a>', webpage_str)
if voice:
    voice = voice.group(1).strip()
    voice = re.search('<a href="(.*?)"', voice)
    if voice:
        voice = voice.group(1).strip()

        for elem in soup(text=re.compile(r'VOICE')):
            voice_text = elem.parent.parent.parent.get_text()
            voice_text = voice_text[6:].strip()
            #print(voice_text)
            #print(voice)
else:
    voice = pd.np.nan
    voice_text = pd.np.nan

# %%
habitat = re.search('HABITAT', webpage_str)
if habitat:
    for elem in soup(text=re.compile(r'HABITAT')):
        habitat = elem.parent.parent.parent.get_text()
        habitat = habitat[8:].strip()
        print(habitat)
else:
    habitat = pd.np.nan
# Out:
# Southern Cassowary frequents mainly the rainforest.  This species prefers virgin forests where it can live free from disturbances.
#     It is often found at medium elevation, in dense  tropical rainforest, but also in galleries and swamp forests.

# %%
description = re.search('DESCRIPTION', webpage_str)
if description:
    for elem in soup(text=re.compile(r'DESCRIPTION')):
        description = elem.parent.parent.parent.get_text()
        description = description[12:].strip()
        print(description)
else:
    description = pd.np.nan
# Out:
# Southern Cassowary is the second largest and tallest  bird after the Ostrich. This species differs in general facts by the female.  She has the criterions of most of the other species’ males, such as brighter  colours, really much larger size, and she does not share the nesting duties  with the male.

# %%
location = re.search('RANGE', webpage_str)
if location:
    for elem in soup(text=re.compile(r'RANGE')):
        location = elem.parent.parent.parent.get_text()
        location = location[6:].strip()
        print(location)
else:
    location = pd.np.nan
# Out:
# Southern Cassowary lives in Aru and Seram Islands  of Indonesia, in New Guinea and NE Australia.

# %%
movements = re.search('MOVEMENTS', webpage_str)
if movements:
    for elem in soup(text=re.compile(r'MOVEMENTS')):
        movements = elem.parent.parent.parent.get_text()
        movements = movements[10:].strip()
        print(movements)
else:
    movements = pd.np.nan
# Out:
# Southern Cassowary does not fly. Its powerful legs and  feet allow it to run at speeds of up to 50 km per hour. It is able to jump up to 5 metres. It also can  swim, and cross lakes and wide rivers without any difficulty.

# %%
reproduction = re.search('REPRODUCTION', webpage_str)
if reproduction:
    for elem in soup(text=re.compile(r'REPRODUCTION')):
        reproduction = elem.parent.parent.parent.get_text()
        reproduction = reproduction[13:].strip()
        print(reproduction)
else:
    reproduction = pd.np.nan
# Out:
# Breeding season starts at the end of the dry season in  New Guinea, and from June to  October in Queensland.
#     The female copulates with several males, and  disappears as soon as the eggs are laid.
#     The nest is a shallow depression scraped in the  ground, with a lining of leaves and grasses. It is very well camouflaged in the  vegetation.
#     She lays 3 to 5 greenish eggs. Incubation by the male  lasts about 50 days. The male rears the chicks during about 9 months.

# %%
diet = re.search('DIET', webpage_str)
if diet:
    for elem in soup(text=re.compile(r'DIET')):
        diet = elem.parent.parent.parent.get_text()
        diet = diet[5:].strip()
        print(diet)
else:
    diet = pd.np.nan
# Out:
# Southern Cassowary feeds mainly on fallen fruits of  different plant’s species. It also consumes invertebrates, small vertebrates  and sometimes carrion.

# %%
protection = re.search('PROTECTION', webpage_str)
if protection:
    for elem in soup(text=re.compile(r'PROTECTION')):
        protection = elem.parent.parent.parent.get_text()
        protection = protection[31:].strip()
        print(protection)
else:
    protection = pd.np.nan
# Out:
# Southern Cassowary is fairly widespread in New Guinea, but  declines due to habitat loss and hunting occurred. Disturbances are also an  important fact in local declines.

# %%
sources = re.search('Sources', webpage_str)
if sources:
    for elem in soup(text=re.compile(r'Sources')):
        sources = elem.parent.parent.parent.parent.get_text()
        sources = sources[sources.find("Sources") + 9:sources.find("Home page")].strip()
        print(sources)
else:
    sources = pd.np.nan
# Out:
# HANDBOOK  OF THE BIRDS OF THE WORLD vol 1 by Josep  del  Hoyo-Andrew Elliot-Jordi Sargatal - Lynx  Edicions - ISBN: 8487334105
# L’ENCYCLOPEDIE MONDIALE DES  OISEAUX - Dr  Christopher M. Perrins -  BORDAS -  ISBN: 2040185607
# Avibase (Lepage Denis)
#
# Birds in backyards (Birds Australia and Australian Museum)
# ARKive (Christopher Parsons)
# El Zoológico Electrónico (Damisela)

# %%
sources.find("Sources")
# Out:
# -1

# %%
sources[sources.find("Sources") + 9:sources.find("Home page")].strip()
# Out:
# 'OF THE BIRDS OF THE WORLD vol 1 by Josep  del  Hoyo-Andrew Elliot-Jordi Sargatal - Lynx  Edicions - ISBN: 8487334105\nL’ENCYCLOPEDIE MONDIALE DES  OISEAUX - Dr  Christopher M. Perrins - \xa0BORDAS -  ISBN: 2040185607\nAvibase (Lepage Denis)\n\nBirds in backyards (Birds Australia and Australian Museum) \nARKive (Christopher Parsons) \nEl Zoológico Electrónico (Damisela'

# %%
birds_list['Height'] = ''
birds_list['Length'] = ''
birds_list['Weight'] = ''
birds_list['Image'] = ''
birds_list['Voice'] = ''
birds_list['Habitat'] = ''
birds_list['Description'] = ''
birds_list['Range'] = ''
birds_list['Movements'] = ''
birds_list['Reproduction'] = ''
birds_list['Diet'] = ''
birds_list['Protection'] = ''
birds_list['Sources'] = ''

# %%
error_list = []
def fetch(idx):
    url = birds_list.ix[idx, 'link']
    req = Request(url, headers={'User-Agent': 'Mozilla/5.0'})
    webpage = urlopen(req).read()
    webpage_str = str(webpage)
    soup = bs(webpage, "lxml")
    imgs_dict = dict()
    
    if len(webpage) == ERROR_PAGE_LEN:
        error_list.append(idx)
        return pd.np.nan
    
    height = re.search('Height:(.*?)<br />', webpage_str)
    if height:
        height = height.group(1).strip()
    else:
        height = pd.np.nan
    
    length = re.search('Length:(.*?)<br />', webpage_str)
    if length:
        length = length.group(1).strip()
    else:
        length = pd.np.nan

    weight = re.search('Weight:(.*?)</p>', webpage_str)
    if weight:
        weight = weight.group(1).strip()
    else:
        weight = pd.np.nan
    
    imgs = soup.find_all("img")
    if imgs:
        imgs = [link_prefix + img['src'] for img in imgs]
    else:
        imgs = pd.np.nan
    
    voice = re.search('VOICE(.*?)</a>', webpage_str)
    if voice:
        voice = voice.group(1).strip()
        voice = re.search('<a href="(.*?)"', voice)
        if voice:
            voice = voice.group(1).strip()

            for elem in soup(text=re.compile(r'VOICE')):
                voice_text = elem.parent.parent.parent.get_text()
                voice_text = voice_text[6:].strip()
                #print(voice_text)
                #print(voice)
    else:
        voice = pd.np.nan
        voice_text = pd.np.nan
    
    habitat = re.search('HABITAT', webpage_str)
    if habitat:
        for elem in soup(text=re.compile(r'HABITAT')):
            habitat = elem.parent.parent.parent.get_text()
            habitat = habitat[8:].strip()
            #print(habitat)
    else:
        habitat = pd.np.nan
    
    description = re.search('DESCRIPTION', webpage_str)
    if description:
        for elem in soup(text=re.compile(r'DESCRIPTION')):
            description = elem.parent.parent.parent.get_text()
            description = description[12:].strip()
            #print(description)
    else:
        description = pd.np.nan
    
    location = re.search('RANGE', webpage_str)
    if location:
        for elem in soup(text=re.compile(r'RANGE')):
            location = elem.parent.parent.parent.get_text()
            location = location[6:].strip()
            #print(location)
    else:
        location = pd.np.nan
    
    movements = re.search('MOVEMENTS', webpage_str)
    if movements:
        for elem in soup(text=re.compile(r'MOVEMENTS')):
            movements = elem.parent.parent.parent.get_text()
            movements = movements[10:].strip()
            #print(movements)
    else:
        movements = pd.np.nan
    
    reproduction = re.search('REPRODUCTION', webpage_str)
    if reproduction:
        for elem in soup(text=re.compile(r'REPRODUCTION')):
            reproduction = elem.parent.parent.parent.get_text()
            reproduction = reproduction[13:].strip()
            #print(reproduction)
    else:
        reproduction = pd.np.nan
    
    diet = re.search('DIET', webpage_str)
    if diet:
        for elem in soup(text=re.compile(r'DIET')):
            diet = elem.parent.parent.parent.get_text()
            diet = diet[5:].strip()
            #print(diet)
    else:
        diet = pd.np.nan
    
    protection = re.search('PROTECTION', webpage_str)
    if protection:
        for elem in soup(text=re.compile(r'PROTECTION')):
            protection = elem.parent.parent.parent.get_text()
            protection = protection[31:].strip()
            #print(protection)
    else:
        protection = pd.np.nan
    
    sources = re.search('Sources', webpage_str)
    if sources:
        for elem in soup(text=re.compile(r'Sources')):
            sources = elem.parent.parent.parent.parent.get_text()
            sources = sources[sources.find("Sources") + 9:sources.find("Home page")].strip()
            #print(sources)
    else:
        sources = pd.np.nan
    
    birds_list.ix[idx, 'Height'] = height
    birds_list.ix[idx, 'Length'] = length
    birds_list.ix[idx, 'Weight'] = weight
    if type(imgs) is float:
        birds_list.ix[idx, 'Image'] = imgs
    else:
        birds_list.ix[idx, 'Image'] = imgs[0]
        imgs_dict[idx] = imgs
    birds_list.ix[idx, 'Voice'] = voice
    birds_list.ix[idx, 'Habitat'] = habitat
    birds_list.ix[idx, 'Description'] = description
    birds_list.ix[idx, 'Range'] = location
    birds_list.ix[idx, 'Movements'] = movements
    birds_list.ix[idx, 'Reproduction'] = reproduction
    birds_list.ix[idx, 'Diet'] = diet
    birds_list.ix[idx, 'Protection'] = protection
    birds_list.ix[idx, 'Sources'] = sources

    imgs_dict[idx] = imgs
    
    return (birds_list.ix[idx], imgs_dict)

# %%
import time
start_time = time.time()

# %%
# Create a new Pool object
multi_pool = Pool(processes=20)
# Extract all info from XML file and assign id_list
new_bird_list = multi_pool.map(fetch, range(200))
# Close Multiprocessing Pool
multi_pool.close()

# %%
# Create a new Pool object
multi_pool = Pool(processes=20)
# Extract all info from XML file and assign id_list
new_bird_list1 = multi_pool.map(fetch, range(200, 400))
# Close Multiprocessing Pool
multi_pool.close()

# %%
# Create a new Pool object
multi_pool = Pool(processes=20)
# Extract all info from XML file and assign id_list
new_bird_list2 = multi_pool.map(fetch, range(400, 600))
# Close Multiprocessing Pool
multi_pool.close()

# %%
# Create a new Pool object
multi_pool = Pool(processes=20)
# Extract all info from XML file and assign id_list
new_bird_list3 = multi_pool.map(fetch, range(600, 800))
# Close Multiprocessing Pool
multi_pool.close()

# %%
# Create a new Pool object
multi_pool = Pool(processes=20)
# Extract all info from XML file and assign id_list
new_bird_list4 = multi_pool.map(fetch, range(800, len(birds_list)))
# Close Multiprocessing Pool
multi_pool.close()

# %%
print(time.time() - start_time)
# Out:
# 102.71105003356934

# %%
birds_list_cleaned = new_bird_list + new_bird_list1 + new_bird_list2 + new_bird_list3 + new_bird_list4
birds_list_cleaned = [bird for bird in birds_list_cleaned if type(bird) is not float]

# %%
len(birds_list_cleaned)
# Out:
# 235

# %%
imgs_list = [bird[1] for bird in birds_list_cleaned]
birds_list_cleaned = [bird[0] for bird in birds_list_cleaned]

# %%
birds_new_df = pd.DataFrame(birds_list_cleaned)
birds_new_df = birds_new_df.rename(columns={'Unnamed: 0': 'Idx'})
birds_new_df.columns
# Out:
# Index(['Idx', 'Common name', 'Binomial', 'Notes', 'Category', 'Order',
#        'Family', 'colour', 'size', 'Common_name_lowercase', 'link', 'Height',
#        'Length', 'Weight', 'Image', 'Voice', 'Habitat', 'Description', 'Range',
#        'Movements', 'Reproduction', 'Diet', 'Protection', 'Sources'],
#       dtype='object')

# %%
imgs_dict = dict()
for imgs in imgs_list:
    imgs_dict.update(imgs)

imgs_df = pd.DataFrame(dict([(k, pd.Series(v)) for k,v in imgs_dict.items()]))

# %%
birds_new_df.to_csv("birds.csv")
imgs_df.to_csv("imgs.csv")

# %%
incomplete_df = birds_list[~birds_list.index.isin(birds_new_df.index)]

# %%
incomplete_df.to_csv("incomplete.csv")
